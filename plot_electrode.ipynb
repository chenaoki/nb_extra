# %%
# !python -V
# Out:
# Python 3.5.2 :: Anaconda custom (64-bit)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plot_all = np.loadtxt?

# %%
plot_all = np.genfromtxt('./20180612_e003_06121541_wave.csv', delimiter=',').T

# %%
plot_all.shape
# Out:
# (74, 5000)

# %%
plot_org = plot_all[:32]
plot_apd = plot_all[32:]

# %%
plot_org.shape
# Out:
# (32, 5000)

# %%
start = 1000
end = 3000

# %%
plt.figure(figsize=(10,20))
for i, wave in enumerate(plot_org):
    plt.subplot(len(plot_org), 1, i+1)
    plt.plot(wave[start:end], label='electrode_{0}'.format(i+1))
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
plt.subplot(211)
plt.plot(plot_org[13][start:end], c='k')
plt.axis('off')
plt.subplot(212)
plt.plot(plot_org[31][start:end], c='k')
plt.axis('off')
# Out:
# (0.0, 2000.0, -1.5, 1.5)
